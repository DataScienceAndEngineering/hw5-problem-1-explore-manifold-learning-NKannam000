# %% [markdown]
# ## Explore Manifold Learning
# Nikhita Kannam
#
# #### Dataset
# CIFAR-10 is a dataset consisting of 60000 32x32 color images. 50,000 of these images are part of the training set and 10,000 are the testing set. They have 10 labels: airplane, automobile, bird, cat, deer, dog, frog, horse, ship and truck.
#
# #### Assignment
# Your goal is to compare different manifold learning algorithms on this data set. You should use the following algorithms:
#
# * Principle Component Analysis
#
# * Isomap Embedding
#
# * Locally Linear Embedding
#
# * Multidimensional scaling.
#
# * SpectralEmbedding
#
# * T-distributed Stochastic Neighbor Embedding
#
#
# All of these algorithms are available in the sklearn library. In addition, you should use also try the UMAP algorithm which is available for python as a library umap. In each of these cases you should project the data into 2D and color the data by the class in which it belongs.
#
# Two references that might help the sklearn documentation and Jake Vanderplas’ book Python Data Science Handbook.  Submit the link to your repository.
#
# Practice creating a well-formatted Jupyter notebook. You should have a title, a description of the data set, a description of the algorithms, a description of the results, and a discussion of the results. You should also have a conclusion. Your notebook should not have lots of code cells with no explanation. It should also not have lots of text outputs. You may need that during your development but by the time you submit, please clean it up.
#
# Submit through HW5:Problem 1: Explore Manifold Learning. Modify the ipython notebook in the repository to include. Sumit your repo link.

# %%
from keras.datasets import cifar10
from sklearn.decomposition import PCA
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
from sklearn.manifold import Isomap
from sklearn.manifold import LocallyLinearEmbedding
from sklearn.manifold import MDS
from sklearn.manifold import SpectralEmbedding
from sklearn.manifold import TSNE
import umap.umap_ as umap
# Out:
# 2023-03-13 20:35:00.863629: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# ### Cleaning up and reshaping data

# %%
reshape_Xtrain = X_train.reshape(50000,3072)
reshape_Xtest = X_test.reshape(10000,3072)
reshape_Ytrain = y_train.reshape(50000,1)
reshape_Ytest = y_test.reshape(10000,1)

# %%
reshape_Xtrain.shape
# Out:
# (50000, 3072)

# %%
reshape_Ytrain.shape
# Out:
# (50000, 1)

# %%
print('Training Images: {}'.format(X_train.shape))
print('Testing Images: {}'.format(X_test.shape))
print('Training Label: {}'.format(y_train.shape))
print('Testing Label: {}'.format(y_test.shape))
# Out:
# Training Images: (50000, 32, 32, 3)
# Testing Images: (10000, 32, 32, 3)
# Training Label: (50000, 1)
# Testing Label: (10000, 1)

# %% [markdown]
# ### List of the labels

# %%
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship','truck']

# %% [markdown]
# ### PCA

# %%
pca = PCA(n_components = 2)
X_train_pca = pca.fit_transform(reshape_Xtrain[:5000])

# %%
figure(figsize=(8, 6), dpi=80)
plt.rcParams["image.cmap"] = "turbo"
plot = plt.scatter(X_train_pca[:,0], X_train_pca[:,1], c=reshape_Ytrain[:5000], s = 15)
plt.legend(handles=plot.legend_elements()[0],labels=labels)
plt.show()

# %% [markdown]
# ### Isomap

# %%
embedding = Isomap(n_components=2)
X_train_I = embedding.fit_transform(reshape_Xtrain[:5000])

# %%
figure(figsize=(8, 6), dpi=80)
plot = plt.scatter(X_train_I[:,0], X_train_I[:,1], c=reshape_Ytrain[:5000], s=15)
plt.legend(handles=plot.legend_elements()[0], labels=labels)
plt.show()

# %% [markdown]
# ### Locally Linear Embedding

# %%
embedding_ll = LocallyLinearEmbedding(n_components=2)
X_train_ll = embedding_ll.fit_transform(reshape_Xtrain[:5000])

# %%
figure(figsize=(8, 6), dpi=80)
plot = plt.scatter(X_train_ll[:,0], X_train_ll[:,1], c=reshape_Ytrain[:5000], s=15)
plt.legend(handles=plot.legend_elements()[0], labels=labels)
plt.show()

# %% [markdown]
# ### Multidimensional scaling

# %%
embedding_MDS = MDS(n_components=2, normalized_stress='auto')
X_train_MDS = embedding_MDS.fit_transform(reshape_Xtrain[:5000])

# %%
figure(figsize=(8, 6), dpi=80)
plot = plt.scatter(X_train_MDS[:,0], X_train_MDS[:,1], c=reshape_Ytrain[:5000], s=15)
plt.legend(handles=plot.legend_elements()[0], labels=labels)
plt.show()

# %% [markdown]
# ### Spectral Embedding

# %%
embedding_se = SpectralEmbedding(n_components=2)
X_train_se = embedding_se.fit_transform(reshape_Xtrain[:5000])

# %%
figure(figsize=(8, 6), dpi=80)
plot = plt.scatter(X_train_se[:,0], X_train_se[:,1], c=reshape_Ytrain[:5000], s=15)
plt.legend(handles=plot.legend_elements()[0], labels=labels)
plt.show()

# %% [markdown]
# ### T-distributed Stochastic Neighbor Embedding

# %%
embedding_tsne = TSNE(n_components=2)
X_train_tnse = embedding_tsne.fit_transform(reshape_Xtrain[:5000])

# %%
figure(figsize=(8, 6), dpi=80)
plot = plt.scatter(X_train_tnse[:,0], X_train_tnse[:,1], c=reshape_Ytrain[:5000], s=15)
plt.legend(handles=plot.legend_elements()[0], labels=labels)
plt.show()

# %% [markdown]
# ### UMAP

# %%
embedding_umap = umap.UMAP()
X_train_umap = embedding_umap.fit_transform(reshape_Xtrain[:5000])

# %%
figure(figsize=(8, 6), dpi=80)
plot = plt.scatter(X_train_umap[:,0], X_train_umap[:,1], c=reshape_Ytrain[:5000], s=15)
plt.legend(handles=plot.legend_elements()[0], labels=labels)
plt.show()
